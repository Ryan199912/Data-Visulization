# %%
#a)	Your name and the title of your data analysis
#Student Name:Ryan
#Student admin Num:P1816233
#Title of Data Analysis: Percentage_expenditure_on_healthcare based on income quintile in SG

#b)	The questions you want to answer to gain deeper insights into the chosen datasets such that you are able to produce an interesting data analysis on it
#The nature of percentage range in different quintile group
#The most and the least frequent percentage of expenditure_on_healthcare

#c)	A list of URLs of all the datasets you have used
#https://data.gov.sg/dataset/household-healthcare-expenditure?view_id=ff0a1c40-d22f-46db-ae9c-9e6a361879cb&resource_id=10882b91-504a-4b5a-8f69-801f7f3436c2
#d)	For each dataset, write Python code that uses the Numpy package to extract useful statistical or summary information about the data and Matplotlib package to produce useful data visualizations that explain the data. 
#e)	For each dataset, explain the nature of that dataset (i.e. what is in that dataset) or any pecularities about it you wish to highlight and explain the process you went through to analyse that dataset.
#f)	For each dataset, describe the insights you have gained from analysing the data and any conclusions or recommendations you want to make as a result of the analysis

import numpy as np

### Read the csv file using genfromtxt
filename = "household-healthcare-expenditure.csv"
data = np.genfromtxt(filename, dtype=['i2', 'i2','U50', 'f4'], 
                     delimiter=',', names=True)

#print(data)


### Print out total rows of data in the file
print(f'There are altogether {len(data)} rows in the data file {filename}')
print()

### Print out the number of periods of data captured
data_start_years = data['period_start']
start_years = np.unique(data_start_years)

data_end_years = data['period_end']
end_years = np.unique(data_end_years)

print(f'There are {len(start_years)} periods of data captured,,which are: ')

for sYear, eYear in zip(start_years, end_years):
    print(f'{sYear}  --  {eYear}')
print()

### Print out the number of income_quintile of data captured
data_income_quintile = data['income_quintile']
income_quintile = np.unique(data_income_quintile) 

print(f'There are {len(income_quintile)} income_quintile of data captured,,which are: ')
print(income_quintile)
print()

### Extract only the rows with certain income_quintile - using boolean indexing
keyword1 = 'All Households'
data_All_Households = data[data['income_quintile'] == keyword1]

keyword2 = '1st quintile'
data_1st = data[data['income_quintile'] == keyword2]
#print(data_1st)

keyword3 = '2nd quintile'
data_2nd = data[data['income_quintile'] == keyword3]
#print(data_2nd)

keyword4 = '3rd quintile'
data_3rd = data[data['income_quintile'] == keyword4]
#print(data_3rd)

keyword5 = '4th quintile'
data_4th = data[data['income_quintile'] == keyword5]
#print(data_4th)

keyword6 = '5th quintile'
data_5th = data[data['income_quintile'] == keyword6]
#print(data_5th)

### Print out the periods which has the highest and the lowest All Household expenditure
max_All_Households = data_All_Households['percentage_expenditure_on_healthcare'].max()
argmax_All_Households  = data_All_Households['percentage_expenditure_on_healthcare'].argmax()
print(f'Period with the highest expenditure percentage in All Households : { data_All_Households[argmax_All_Households]["period_start"]} - {data_All_Households[argmax_All_Households]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { max_All_Households:.1f} ')
print()
min_All_Households = data_All_Households['percentage_expenditure_on_healthcare'].min()
argmin_All_Households  = data_All_Households['percentage_expenditure_on_healthcare'].argmin()
print(f'Period with the lowest expenditure percentage in All Households : { data_All_Households[argmin_All_Households]["period_start"]} - {data_All_Households[argmin_All_Households]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { min_All_Households:.1f} ')
print()

### Print out the periods which has the highest and the lowest 1st expenditure
max_1st = data_1st['percentage_expenditure_on_healthcare'].max()
argmax_1st = data_1st['percentage_expenditure_on_healthcare'].argmax()
print(f'Period with the highest expenditure percentage in 1st : { data_1st[argmax_1st]["period_start"]} - {data_1st[argmax_1st]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { max_1st:.1f} ')
print()
min_1st = data_1st['percentage_expenditure_on_healthcare'].min()
argmin_1st = data_1st['percentage_expenditure_on_healthcare'].argmin()
print(f'Period with the lowest expenditure percentage in 1st : { data_1st[argmin_1st]["period_start"]} - {data_1st[argmin_1st]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { min_1st:.1f} ')
print()

### Print out the periods which has the highest and the lowest 2nd expenditure
max_2nd = data_2nd['percentage_expenditure_on_healthcare'].max()
argmax_2nd = data_2nd['percentage_expenditure_on_healthcare'].argmax()
print(f'Period with the highest expenditure percentage in 2nd : { data_2nd[argmax_2nd]["period_start"]} - {data_2nd[argmax_2nd]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { max_2nd:.1f} ')
print()
min_2nd = data_2nd['percentage_expenditure_on_healthcare'].min()
argmin_2nd = data_2nd['percentage_expenditure_on_healthcare'].argmin()
print(f'Period with the lowest expenditure percentage in 2nd : { data_2nd[argmin_2nd]["period_start"]} - {data_2nd[argmin_2nd]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { min_2nd:.1f} ')
print()

### Print out the periods which has the highest and the lowest 3rd expenditure
max_3rd = data_3rd['percentage_expenditure_on_healthcare'].max()
argmax_3rd = data_3rd['percentage_expenditure_on_healthcare'].argmax()
print(f'Period with the highest expenditure percentage in 3rd : { data_3rd[argmax_3rd]["period_start"]} - {data_3rd[argmax_3rd]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { max_3rd:.1f} ')
print()
min_3rd = data_3rd['percentage_expenditure_on_healthcare'].min()
argmin_3rd = data_3rd['percentage_expenditure_on_healthcare'].argmin()
print(f'Period with the lowest expenditure percentage in 3rd : { data_3rd[argmin_3rd]["period_start"]} - {data_2nd[argmin_3rd]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { min_3rd:.1f} ')
print()

### Print out the periods which has the highest and the lowest 4th expenditure
max_4th = data_4th['percentage_expenditure_on_healthcare'].max()
argmax_4th = data_4th['percentage_expenditure_on_healthcare'].argmax()
print(f'Period with the highest expenditure percentage in 4th : { data_4th[argmax_4th]["period_start"]} - {data_4th[argmax_4th]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { max_4th:.1f} ')
print()
min_4th = data_4th['percentage_expenditure_on_healthcare'].min()
argmin_4th = data_4th['percentage_expenditure_on_healthcare'].argmin()
print(f'Period with the lowest expenditure percentage in 4th : { data_4th[argmin_4th]["period_start"]} - {data_4th[argmin_4th]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { min_4th:.1f} ')
print()

### Print out the periods which has the highest and the lowest 5th expenditure
max_5th = data_5th['percentage_expenditure_on_healthcare'].max()
argmax_5th = data_5th['percentage_expenditure_on_healthcare'].argmax()
print(f'Period with the highest expenditure percentage in 5th : { data_5th[argmax_5th]["period_start"]} - {data_5th[argmax_5th]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { max_5th:.1f} ')
print()
min_5th = data_5th['percentage_expenditure_on_healthcare'].min()
argmin_5th = data_5th['percentage_expenditure_on_healthcare'].argmin()
print(f'Period with the lowest expenditure percentage in 5th : { data_5th[argmin_5th]["period_start"]} - {data_5th[argmin_5th]["period_end"]}')
print(f'Percentage_expenditure_on_healthcare: { min_5th:.1f} ')
print()
# Out:
# There are altogether 24 rows in the data file household-healthcare-expenditure.csv
#
# There are 4 periods of data captured,,which are:
# 2002  --  2003
# 2007  --  2008
# 2012  --  2013
# 2017  --  2018
#
# There are 6 income_quintile of data captured,,which are:
# ['1st quintile' '2nd quintile' '3rd quintile' '4th quintile'
#  '5th quintile' 'All Households']
#
# Period with the highest expenditure percentage in All Households : 2017 - 2018
# Percentage_expenditure_on_healthcare: 5.5
#
# Period with the lowest expenditure percentage in All Households : 2012 - 2013
# Percentage_expenditure_on_healthcare: 4.5
#
# Period with the highest expenditure percentage in 1st : 2017 - 2018
# Percentage_expenditure_on_healthcare: 7.8
#
# Period with the lowest expenditure percentage in 1st : 2012 - 2013
# Percentage_expenditure_on_healthcare: 5.6
#
# Period with the highest expenditure percentage in 2nd : 2017 - 2018
# Percentage_expenditure_on_healthcare: 5.7
#
# ...

# %%
#This sample output uses the Matplotlib library to plot a box chart and a histgram to allow the user to perform a simple data analysis of percentage_expenditure_on_healthcare based on income quntile in SG

#From the boxplot, it shows that all the range except the 4th income quintile are quite wide. It is interested to note that only 1st income_quintile has a outliers over the range.

import matplotlib.pyplot as plt
import numpy as np

#Extract expenditure percentage in different income quintile
the1st_percentage = data_1st["percentage_expenditure_on_healthcare"]

the2nd_percentage = data_2nd["percentage_expenditure_on_healthcare"]

the3rd_percentage = data_3rd["percentage_expenditure_on_healthcare"]

the4th_percentage = data_4th["percentage_expenditure_on_healthcare"]

the5th_percentage = data_5th["percentage_expenditure_on_healthcare"]

all_households_percentage = data_All_Households["percentage_expenditure_on_healthcare"]

#set up the y values
y_values = np.array([the1st_percentage, the2nd_percentage, the3rd_percentage, the4th_percentage,the5th_percentage,all_households_percentage,])

#set up the labels on the x-axis
x_labels = income_quintile
x_ticks = np.arange(len(x_labels))
plt.xticks(rotation=90)
plt.boxplot(y_values.transpose(),labels=x_labels, patch_artist=True)
plt.title(" Household Healthcare Expenditure Percentage Box Plot  ")
plt.xlabel("Income Quintile")
plt.ylabel("Expenditure percentage")
plt.show()

# %%
#From the histgram, it shows that the percentage with the highest frequcy is around 5 and the lowest is 7.5. And there is a blank between 6 and 7.5

import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

data_percentage = data['percentage_expenditure_on_healthcare']
plt.hist(data_percentage)
#print(data_percentage)

plt.title("Percentage Expenditure Histogram")
plt.xlabel("Income quintile")
plt.ylabel("Frequency")

plt.show()

#According to the analysing of this dataset,the rich spend more on health care while the proverty pay less to health care.
#Therefore,policy in healthcare guarantee for the poor should be made and medical allowance should be provided to rise people's health care,especial in the poor
